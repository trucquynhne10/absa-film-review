# %% [markdown]
# ## Movie review tagging model training - Data Science

# %% [markdown]
# ### Data preparation

# %% [markdown]
# #### Preprocessed dataset reading

# %%
import numpy as np
import pandas as pd

df_train = pd.read_csv(r'D:\Project\EC - Socail media\ABSA\Me\dataset\DataProcessed\train_processed.csv')
df_test = pd.read_csv(r'D:\Project\EC - Socail media\ABSA\Me\dataset\DataProcessed\test_processed.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   character      477 non-null    object
#  1   content        477 non-null    object
#  2   scene          477 non-null    object
#  3   sound          477 non-null    object
#  4   Cmt            477 non-null    object
#  5   processed_cmt  477 non-null    object
# dtypes: object(6)
# memory usage: 22.5+ KB

# %%
df_train = df_train.dropna(how='any')

# %%
df_train[df_train["processed_cmt"].isnull()]
# Out:
# Empty DataFrame
# Columns: [character, content, scene, sound, Cmt, processed_cmt]
# Index: []

# %%
import pickle
y_train = pickle.load(open(r'D:\Project\EC - Socail media\ABSA\Me\dataset\Label\Label\label_aspect_train.pkl', 'rb'))
y_test = pickle.load(open(r'D:\Project\EC - Socail media\ABSA\Me\dataset\Label\Label\label_aspect_test.pkl', 'rb'))

# %%
y_train = y_train.drop(index = [154, 2113, 3699])

# %%
y_train.to_pickle('label_aspect_train.pkl')
df_train.to_csv('train_processed.csv', encoding = 'utf-8-sig', index = False)

# %% [markdown]
# #### Data vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=1000, ngram_range=(1, 2), min_df=2, max_df=0.8)

corpus = df_train['processed_cmt']
corpus_test = df_test['processed_cmt']
X_train = tfidf.fit_transform(corpus).toarray()
X_test = tfidf.fit_transform(corpus).toarray()

# %% [markdown]
# #### Data split

# %%
from sklearn.model_selection import train_test_split


print(X_train.shape), print(y_train.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (3806, 1000)
# (3806, 4)
# (3806, 1000)
# (477, 4)
# (None, None)

# %%
y_train
# Out:
#       is_character  is_content  is_scene  is_sound
# 0                0           1         0         1
# 1                0           0         1         0
# 2                0           1         0         0
# 3                0           0         1         0
# 4                0           1         1         0
# ...            ...         ...       ...       ...
# 3804             0           0         1         1
# 3805             0           0         0         0
# 3806             0           0         0         0
# 3807             0           0         0         1
# 3808             1           1         1         0
#
# [3809 rows x 4 columns]

# %% [markdown]
# ### Model Training

# %%
from sklearn.metrics import accuracy_score, hamming_loss
from sklearn.model_selection import GridSearchCV

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

best_model_method = None
best_model_params = {}
best_model_f1_score = 0

# %% [markdown]
# #### Using BinaryRelevance method
#
# The `BinaryRelevance` method is an approach used in multi-label classification problems, where each instance can belong to multiple classes (labels) simultaneously. It transforms a multi-label problem into multiple independent binary classification problems, one for each label.
#
# How It Works:
# - For each label, `Binary Relevance` creates a separate binary classification problem.
# - Each classifier predicts whether or not a particular label applies to a given instance, treating each label as independent from the others.
# - The final prediction is a combination of all individual binary classifiers’ predictions.
#
# Advantages:
# - Simple to implement.
# - Works well when the labels are independent of each other.
#
# Limitations:
# - Label independence assumption: It assumes that labels are independent, which might not be the case in real-world datasets (some labels might be correlated).
# - Requires training multiple classifiers, which can increase computational cost.

# %%
from skmultilearn.problem_transform import BinaryRelevance

parameters = [
    {
        'classifier': [MultinomialNB()],
        'classifier__alpha': [0.7, 1.0, 1.3],
    },
    {
        'classifier': [RandomForestClassifier()],
        'classifier__criterion': ['gini', 'entropy'],
        'classifier__n_estimators': [50, 100, 150],
    },
    {
        'classifier': [KNeighborsClassifier()],
        'classifier__n_neighbors': [2, 3, 5, 8, 9],
        'classifier__weights': ['uniform', 'distance'],
    },
    {
        'classifier': [SVC()],
        'classifier__C': [0.01, 0.1, 1.0],
        'classifier__kernel': ['linear', 'rbf', 'sigmoid'],
    },
    {
        'classifier': [LogisticRegression()],
        'classifier__C': [0.01, 0.1, 1.0],
        'classifier__max_iter': [50, 100, 200],
    }
]

scores = ['f1_micro', 'f1_macro', 'precision_micro', 'precision_macro', 'recall_micro', 'recall_macro']
clf = GridSearchCV(BinaryRelevance(), parameters, scoring=scores, refit=False)
clf.fit(X_train, y_train)

print('\nAccuracy for each parameter set:')
for i in range(len(clf.cv_results_['params'])):
    for scorer in scores:
        mean_score = clf.cv_results_[f'mean_test_{scorer}'][i]
        print(f'Parameter set {i+1}: {clf.cv_results_["params"][i]} - Mean {scorer}: {mean_score}')
    print('\n')
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy for each parameter set:
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean f1_micro: 0.657515746524119
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean f1_macro: 0.644455513292933
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean precision_micro: 0.7263386406644855
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean precision_macro: 0.7589880524086785
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean recall_micro: 0.6007357944567221
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean recall_macro: 0.5910534498420539
#
#
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean f1_micro: 0.6472962015115628
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean f1_macro: 0.6313713901308508
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean precision_micro: 0.7323721375104619
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean precision_macro: 0.7674583034204296
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean recall_micro: 0.5801008359108026
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean recall_macro: 0.5707568301609848
#
#
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean f1_micro: 0.6412551669958895
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean f1_macro: 0.6236090322137049
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean precision_micro: 0.7382943802207226
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean precision_macro: 0.7766071625846351
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean recall_micro: 0.5669506127184505
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean recall_macro: 0.5579010694598424
#
#
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean f1_micro: 0.7749532250148112
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean f1_macro: 0.7774011838219804
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean precision_micro: 0.8447522641599068
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean precision_macro: 0.8537004112103043
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean recall_micro: 0.71584649530341
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean recall_macro: 0.7186171177785289
#
#
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean f1_micro: 0.7817149288985756
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean f1_macro: 0.7837441534527999
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean precision_micro: 0.8444177519012224
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean precision_macro: 0.8547934711883075
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean recall_micro: 0.7277384474766715
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean recall_macro: 0.729379680946535
#
#
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean f1_micro: 0.7820677676243765
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean f1_macro: 0.7839404185644555
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean precision_micro: 0.8468824464204797
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean precision_macro: 0.8565241369610718
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean recall_micro: 0.7265363893087758
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean recall_macro: 0.7284670510722167
#
#
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean f1_micro: 0.7644409633683259
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean f1_macro: 0.7661991540355289
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean precision_micro: 0.8462248478858415
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean precision_macro: 0.8571279303277042
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean recall_micro: 0.6971082961559756
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean recall_macro: 0.6989410718452584
#
#
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean f1_micro: 0.773765207520528
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean f1_macro: 0.7751938625507175
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean precision_micro: 0.8500113700095315
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean precision_macro: 0.8596937001149072
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean recall_micro: 0.7101529590198655
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean recall_macro: 0.7118725605306231
#
#
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean f1_micro: 0.7751317489876225
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean f1_macro: 0.7765402184480985
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean precision_micro: 0.8538619182074518
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean precision_macro: 0.8640701360409533
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean recall_micro: 0.7097899542893293
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean recall_macro: 0.7117192074374952
#
#
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.18364388849260538
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.1891807768101037
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.9015716283573113
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.7946516733537194
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.10232010751266944
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.1153972816349419
#
#
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean f1_micro: 0.26880217835985765
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean f1_macro: 0.2719330166496047
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean precision_micro: 0.7347807920510521
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean precision_macro: 0.6821784265180396
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean recall_micro: 0.16465979015889562
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean recall_macro: 0.18061056679577212
#
#
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.2057894871727748
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.21009583533371626
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.827631048904905
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.7203947658854519
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.11762776728222919
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.1316249901076235
#
#
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean f1_micro: 0.21406394502610993
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean f1_macro: 0.2189029008796434
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8429757161720755
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean precision_macro: 0.7502749057030733
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean recall_micro: 0.12275366225735138
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean recall_macro: 0.13691974771556487
#
#
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.16187111537985838
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.16642233869470185
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8188398695072199
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.7039841763082961
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.08999003089294616
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.10126118856537084
#
#
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean f1_micro: 0.17773280787790008
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean f1_macro: 0.18330481155873182
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8520950089729024
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean precision_macro: 0.7803428422955235
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean recall_micro: 0.09941899400961943
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean recall_macro: 0.11110329372527343
#
#
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.08755533096048589
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.09366903690124195
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.86618310950131
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.7322092286798169
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.046151830314106225
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.0528291626842625
#
#
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean f1_micro: 0.15049695722873865
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean f1_macro: 0.15748073506143195
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8914690401219889
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean precision_macro: 0.8789137037230059
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean recall_micro: 0.08231107162689788
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean recall_macro: 0.09182670711809496
#
#
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.09349000998938026
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.09954048574106647
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8526066746568806
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.698657249183565
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.049499063816269694
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.05650102804692906
#
#
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean f1_micro: 0.12683123213910402
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean f1_macro: 0.13414558164374984
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8915599750857639
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean precision_macro: 0.8418323502669478
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean recall_micro: 0.06834339255341462
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean recall_macro: 0.0763056599700661
#
#
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.0
#
#
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.0
#
#
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.0
#
#
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.5437309408773913
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.500390199339208
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.867955862947569
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.9125837032472368
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.3959371290920906
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.3900058488441983
#
#
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.1346880802282642
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.12401935889051452
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.928238196988197
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.7235762537237056
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.07268658782061979
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.07099835115444009
#
#
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.5393941275167202
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.4951632224066781
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.866684568908795
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.9105289593823688
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.39160289370444606
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.385763257683545
#
#
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.768460750138026
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.772289578311886
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.8430324929242738
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.8557724037108873
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.7061113272328082
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.7067343633667613
#
#
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.7450722852814008
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.7442384970099714
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.8610948205526651
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.8754869047385494
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.656787384685524
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.6536213187597648
#
#
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.7625511915676201
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.7660733162004305
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.8399710923947709
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.8528789877259257
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.6982545896350285
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.6986858819898989
#
#
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean f1_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean f1_macro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean precision_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean precision_macro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean recall_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean recall_macro: 0.0
#
#
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean f1_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean f1_macro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean precision_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean precision_macro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean recall_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean recall_macro: 0.0
#
#
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean f1_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean f1_macro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean precision_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean precision_macro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean recall_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean recall_macro: 0.0
#
#
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean f1_micro: 0.41362266890870786
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean f1_macro: 0.37571008982958864
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean precision_micro: 0.8731690677829951
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean precision_macro: 0.9213542241544952
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean recall_micro: 0.2711033929427903
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean recall_macro: 0.26126569450883175
#
#
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean f1_micro: 0.41362266890870786
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean f1_macro: 0.37571008982958864
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean precision_micro: 0.8731690677829951
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean precision_macro: 0.9213542241544952
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean recall_micro: 0.2711033929427903
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean recall_macro: 0.26126569450883175
#
#
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean f1_micro: 0.41362266890870786
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean f1_macro: 0.37571008982958864
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean precision_micro: 0.8731690677829951
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean precision_macro: 0.9213542241544952
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean recall_micro: 0.2711033929427903
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean recall_macro: 0.26126569450883175
#
#
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean f1_micro: 0.7276791548921742
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean f1_macro: 0.7257729453069499
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean precision_micro: 0.849009348705775
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean precision_macro: 0.863373073704486
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean recall_micro: 0.6369579686698953
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean recall_macro: 0.632783509461062
#
#
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean f1_micro: 0.7276791548921742
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean f1_macro: 0.7257729453069499
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean precision_micro: 0.849009348705775
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean precision_macro: 0.863373073704486
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean recall_micro: 0.6369579686698953
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean recall_macro: 0.632783509461062
#
#
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean f1_micro: 0.7276791548921742
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean f1_macro: 0.7257729453069499
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean precision_micro: 0.849009348705775
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean precision_macro: 0.863373073704486
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean recall_micro: 0.6369579686698953
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean recall_macro: 0.632783509461062

# %%
# Display the best parameter and create the best model
best_score_idx = clf.cv_results_['mean_test_f1_micro'].argmax()
best_params = {k.replace('classifier__', ''): v for k, v in clf.cv_results_['params'][best_score_idx].items()}
print(f'Best parameters: {best_params}')

f1_micro_score = clf.cv_results_['mean_test_f1_micro'][best_score_idx]
print('Mean f1_micro score:', f1_micro_score)

if f1_micro_score > best_model_f1_score:
    best_model_method = 'BinaryRelevance'
    best_model_params = best_params
    best_model_f1_score = f1_micro_score
# Out:
# Best parameters: {'classifier': RandomForestClassifier(), 'criterion': 'gini', 'n_estimators': 150}
# Mean f1_micro score: 0.7820677676243765

# %% [markdown]
# #### Using LabelPowerset method
#
# The `Label Powerset` method is another popular approach used in multi-label classification. Unlike `Binary Relevance`, which treats each label as independent, `Label Powerset` considers the combinations of labels and treats each unique set of labels as a single label in a multi-class classification problem.
#
# How It Works:
# - The idea behind `Label Powerset` is to transform the multi-label classification problem into a single-label multi-class classification problem.
# - Each unique combination of labels in the dataset is treated as a separate class.
# - A single classifier is trained on these unique label combinations.
#
# Advantages:
# - Considers label dependencies: By treating label combinations as classes, it captures the relationships between labels.
# - Can perform well in cases where certain label combinations are frequent and meaningful.
#
# Limitations:
# - Scalability: If there are many possible combinations of labels, the number of classes grows exponentially, which can make the problem very large and computationally expensive.
# - Rare combinations: Some combinations of labels might occur very infrequently, which can make the model struggle to generalize to new instances with rare combinations.

# %%
from skmultilearn.problem_transform import LabelPowerset

parameters = [
    {
        'classifier': [MultinomialNB()],
        'classifier__alpha': [0.7, 1.0, 1.3],
    },
    {
        'classifier': [RandomForestClassifier()],
        'classifier__criterion': ['gini', 'entropy'],
        'classifier__n_estimators': [50, 100, 150],
    },
    {
        'classifier': [KNeighborsClassifier()],
        'classifier__n_neighbors': [2, 3, 5, 8, 9],
        'classifier__weights': ['uniform', 'distance'],
    },
    {
        'classifier': [SVC()],
        'classifier__C': [0.01, 0.1, 1.0],
        'classifier__kernel': ['linear', 'rbf', 'sigmoid'],
    },
    {
        'classifier': [LogisticRegression()],
        'classifier__C': [0.01, 0.1, 1.0],
        'classifier__max_iter': [50, 100, 200],
    }
]

scores = ['f1_micro', 'f1_macro', 'precision_micro', 'precision_macro', 'recall_micro', 'recall_macro']
clf = GridSearchCV(LabelPowerset(), parameters, scoring=scores, refit=False)
clf.fit(X_train, y_train)

print('\nAccuracy for each parameter set:')
for i in range(len(clf.cv_results_['params'])):
    for scorer in scores:
        mean_score = clf.cv_results_[f'mean_test_{scorer}'][i]
        print(f'Parameter set {i+1}: {clf.cv_results_["params"][i]} - Mean {scorer}: {mean_score}')
    print('\n')
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy for each parameter set:
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean f1_micro: 0.5493733795573894
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean f1_macro: 0.5486651559389991
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean precision_micro: 0.826912837452104
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean precision_macro: 0.8256077698150579
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean recall_micro: 0.4115974238661323
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean recall_macro: 0.4184553061784258
#
#
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean f1_micro: 0.49959971588450813
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean f1_macro: 0.4964185794040675
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean precision_micro: 0.8336698608414419
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean precision_macro: 0.833573352799211
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean recall_micro: 0.3567620297478826
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean recall_macro: 0.3669096509241028
#
#
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean f1_micro: 0.45318659476725076
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean f1_macro: 0.44783133685354437
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean precision_micro: 0.8384420827720829
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean precision_macro: 0.842232607477446
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean recall_micro: 0.31052803428020725
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean recall_macro: 0.3241061329905855
#
#
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean f1_micro: 0.6568208458045428
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean f1_macro: 0.6571721225792209
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean precision_micro: 0.8271026431573066
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean precision_macro: 0.8287320966481684
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean recall_micro: 0.5449352402377408
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean recall_macro: 0.5471695359512675
#
#
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean f1_micro: 0.6663970507377833
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean f1_macro: 0.6661014270347886
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean precision_micro: 0.8361509292156623
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean precision_macro: 0.8378758143151908
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean recall_micro: 0.554283055560729
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean recall_macro: 0.555284312542548
#
#
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean f1_micro: 0.6727988269592603
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean f1_macro: 0.6723950895054736
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean precision_micro: 0.8393659822786235
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean precision_macro: 0.8399112075867258
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean recall_micro: 0.5617240896551133
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean recall_macro: 0.5628558332069563
#
#
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean f1_micro: 0.6374359739293898
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean f1_macro: 0.639001488513036
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean precision_micro: 0.821172320083859
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean precision_macro: 0.8214351129337022
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean recall_micro: 0.5216676618850297
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean recall_macro: 0.5261522203763221
#
#
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean f1_micro: 0.6343462959996378
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean f1_macro: 0.6358744611995786
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean precision_micro: 0.8386529190808784
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean precision_macro: 0.8376995913593195
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean recall_micro: 0.5102784632133434
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean recall_macro: 0.5149463651549823
#
#
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean f1_micro: 0.6335691698165908
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean f1_macro: 0.6356236001363288
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean precision_micro: 0.838342300534389
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean precision_macro: 0.8371765030449845
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean recall_micro: 0.5093608038798367
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean recall_macro: 0.5157323736449139
#
#
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.21340329207627828
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.22145207310796722
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.7452365787280398
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6828949848297337
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.1246403454233755
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.13671012667227178
#
#
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean f1_micro: 0.26980979909270697
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean f1_macro: 0.2731296953276308
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean precision_micro: 0.7344763279785967
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean precision_macro: 0.6851504544900674
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean recall_micro: 0.16543492929131923
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean recall_macro: 0.18128743860666457
#
#
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.2041154683290083
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.2096316925282664
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8024801302587108
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6989024679158627
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.1170556478672965
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.13003541026960783
#
#
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean f1_micro: 0.21758241907600312
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean f1_macro: 0.22248660938785259
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8146114301695985
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean precision_macro: 0.7244495570955738
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean recall_micro: 0.12572489558866295
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean recall_macro: 0.13967597410267302
#
#
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.16344580918709445
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.16866606668475645
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8008507450652139
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6982668627620898
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.09116548550122637
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.1018777497476661
#
#
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean f1_micro: 0.19054184466673146
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean f1_macro: 0.19552676928623408
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8261108984175605
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean precision_macro: 0.788966775179826
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean recall_micro: 0.10783119936992946
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean recall_macro: 0.12058005098934607
#
#
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.11508700195500152
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.12162121422715273
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.7941550077725961
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.7168036752035076
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.06206869242211597
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.06972677933106611
#
#
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean f1_micro: 0.1513024019072363
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean f1_macro: 0.158038347577742
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8577616589258825
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean precision_macro: 0.8405012771483579
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean recall_micro: 0.08307275550495538
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean recall_macro: 0.09249243628511725
#
#
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.1004369764983392
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.10656563502386995
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.7921374128854948
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6124718237203935
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.05363728456755347
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.060352350327218175
#
#
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean f1_micro: 0.13982109713542915
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean f1_macro: 0.14684045489564998
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8567782723133135
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean precision_macro: 0.7413990314238535
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean recall_micro: 0.07619910677695067
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean recall_macro: 0.08503529880782763
#
#
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.0
#
#
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.0
#
#
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.0
#
#
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.24979104594074256
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.23217488977666548
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.8461161138238389
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.8611715831953628
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.14664460605632818
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.16916639980957882
#
#
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.09410890803591308
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.09791040448454019
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.8882781341300522
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.4699776693894341
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.04969113306367617
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.060757646867022896
#
#
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.24893856812192627
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.2302703204164065
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.8394585734393132
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.8607490743938063
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.14624809993259946
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.16868858011676932
#
#
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.6943511150183488
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.6950997042576247
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.8190615169669228
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.8281748810650807
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.6027935693897042
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.601446048422917
#
#
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.629404065796151
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.6304571206969137
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.8583663028068342
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.8622384682283272
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.49695003859264597
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.4981730309348893
#
#
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.6891894081328862
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.6896148811285825
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.8267352160604904
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.8361143345265505
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.5910553097626066
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.5896166737545505
#
#
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean f1_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean f1_macro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean precision_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean precision_macro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean recall_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean recall_macro: 0.0
#
#
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean f1_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean f1_macro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean precision_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean precision_macro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean recall_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean recall_macro: 0.0
#
#
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean f1_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean f1_macro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean precision_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean precision_macro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean recall_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean recall_macro: 0.0
#
#
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean f1_micro: 0.29178447741724634
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean f1_macro: 0.2751606508127281
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean precision_micro: 0.8558697509869043
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean precision_macro: 0.889418438630463
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean recall_micro: 0.17591973193487642
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean recall_macro: 0.19727492725063747
#
#
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean f1_micro: 0.29178447741724634
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean f1_macro: 0.2751606508127281
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean precision_micro: 0.8558697509869043
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean precision_macro: 0.889418438630463
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean recall_micro: 0.17591973193487642
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean recall_macro: 0.19727492725063747
#
#
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean f1_micro: 0.29178447741724634
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean f1_macro: 0.2751606508127281
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean precision_micro: 0.8558697509869043
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean precision_macro: 0.889418438630463
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean recall_micro: 0.17591973193487642
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean recall_macro: 0.19727492725063747
#
#
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean f1_micro: 0.6585625422104283
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean f1_macro: 0.6594844184942822
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean precision_micro: 0.8437922169101906
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean precision_macro: 0.8488376476530632
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean recall_micro: 0.5400305053567808
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean recall_macro: 0.5409010969239325
#
#
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean f1_micro: 0.6584761818286403
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean f1_macro: 0.659252416025084
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean precision_micro: 0.8444703455934983
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean precision_macro: 0.849300770051952
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean recall_micro: 0.5396374582183278
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean recall_macro: 0.5404411751850239
#
#
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean f1_micro: 0.6584761818286403
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean f1_macro: 0.659252416025084
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean precision_micro: 0.8444703455934983
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean precision_macro: 0.849300770051952
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean recall_micro: 0.5396374582183278
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean recall_macro: 0.5404411751850239

# %%
# Display the best parameter and create the best model
best_score_idx = clf.cv_results_['mean_test_f1_micro'].argmax()
best_params = {k.replace('classifier__', ''): v for k, v in clf.cv_results_['params'][best_score_idx].items()}
print(f'Best parameters: {best_params}')

f1_micro_score = clf.cv_results_['mean_test_f1_micro'][best_score_idx]
print('Mean f1_micro score:', f1_micro_score)

if f1_micro_score > best_model_f1_score:
    best_model_method = 'LabelPowerset'
    best_model_params = best_params
    best_model_f1_score = f1_micro_score
# Out:
# Best parameters: {'classifier': SVC(), 'C': 1.0, 'kernel': 'linear'}
# Mean f1_micro score: 0.6943511150183488

# %% [markdown]
# #### Using Classifier Chain method
#
# The `Classifier Chain` is another advanced method used in multi-label classification. It combines the ideas of `Binary Relevance` and `Label Powerset`, capturing both the individual label characteristics and the dependencies between labels.
#
# How It Works:
# - `Classifier Chain` transforms the multi-label classification problem into a sequence of binary classification problems.
# - Each classifier in the chain predicts whether a specific label applies to an instance, using not only the input features but also the predictions of the previous classifiers in the chain.
# - This allows the model to capture dependencies between labels because the prediction for a label can depend on the predictions for other labels made earlier in the chain.
#
# Advantages:
# - Captures label dependencies: Unlike Binary Relevance, which treats labels independently, Classifier Chain captures the relationships between labels by conditioning on previously predicted labels.
# - Flexible and efficient: It provides a balance between simple methods like Binary Relevance and complex methods like Label Powerset.
#
# Limitations:
# - Order of labels matters: The performance of the model can be sensitive to the order in which the labels are processed in the chain. Sometimes, a suboptimal chain order may degrade the performance.
# - Computational cost: Since each label prediction depends on previous ones, the process can be slower than Binary Relevance but generally faster than Label Powerset.

# %%
from skmultilearn.problem_transform import ClassifierChain

parameters = [
    {
        'classifier': [MultinomialNB()],
        'classifier__alpha': [0.7, 1.0, 1.3],
    },
    {
        'classifier': [RandomForestClassifier()],
        'classifier__criterion': ['gini', 'entropy'],
        'classifier__n_estimators': [50, 100, 150],
    },
    {
        'classifier': [KNeighborsClassifier()],
        'classifier__n_neighbors': [2, 3, 5, 8, 9],
        'classifier__weights': ['uniform', 'distance'],
    },
    {
        'classifier': [SVC()],
        'classifier__C': [0.01, 0.1, 1.0],
        'classifier__kernel': ['linear', 'rbf', 'sigmoid'],
    },
    {
        'classifier': [LogisticRegression()],
        'classifier__C': [0.01, 0.1, 1.0],
        'classifier__max_iter': [50, 100, 200],
    }
]

scores = ['f1_micro', 'f1_macro', 'precision_micro', 'precision_macro', 'recall_micro', 'recall_macro']
clf = GridSearchCV(ClassifierChain(), parameters, scoring=scores, refit=False)
clf.fit(X_train, y_train)

print('\nAccuracy for each parameter set:')
for i in range(len(clf.cv_results_['params'])):
    for scorer in scores:
        mean_score = clf.cv_results_[f'mean_test_{scorer}'][i]
        print(f'Parameter set {i+1}: {clf.cv_results_["params"][i]} - Mean {scorer}: {mean_score}')
    print('\n')
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy for each parameter set:
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean f1_micro: 0.659915041865978
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean f1_macro: 0.6506164236040645
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean precision_micro: 0.7167178200891732
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean precision_macro: 0.7395503262273451
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean recall_micro: 0.6116558674242072
# Parameter set 1: {'classifier': MultinomialNB(), 'classifier__alpha': 0.7} - Mean recall_macro: 0.6033707144755384
#
#
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean f1_micro: 0.6548772575312118
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean f1_macro: 0.6444302123477202
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean precision_micro: 0.7253047872465022
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean precision_macro: 0.7516195620873818
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean recall_micro: 0.5971526767477621
# Parameter set 2: {'classifier': MultinomialNB(), 'classifier__alpha': 1.0} - Mean recall_macro: 0.5891781948657212
#
#
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean f1_micro: 0.6495643111035438
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean f1_macro: 0.6377828178870112
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean precision_micro: 0.7337077744715691
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean precision_macro: 0.7624124315560851
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean recall_micro: 0.5829786415165613
# Parameter set 3: {'classifier': MultinomialNB(), 'classifier__alpha': 1.3} - Mean recall_macro: 0.5752577242377211
#
#
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean f1_micro: 0.7756919096181736
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean f1_macro: 0.7789969140980896
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean precision_micro: 0.8391999665293502
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean precision_macro: 0.8468744421947326
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean recall_micro: 0.7212497926203737
# Parameter set 4: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 50} - Mean recall_macro: 0.7246991487042116
#
#
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean f1_micro: 0.778031593581918
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean f1_macro: 0.7808368711209744
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean precision_micro: 0.833363475508507
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean precision_macro: 0.8422490960635824
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean recall_micro: 0.7296367776760404
# Parameter set 5: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 100} - Mean recall_macro: 0.7316181653206542
#
#
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean f1_micro: 0.781287681264449
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean f1_macro: 0.7843639797571413
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean precision_micro: 0.8419324270147932
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean precision_macro: 0.8509393486031722
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean recall_micro: 0.7288893394902036
# Parameter set 6: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'gini', 'classifier__n_estimators': 150} - Mean recall_macro: 0.7313344560972386
#
#
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean f1_micro: 0.7637002565967619
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean f1_macro: 0.7665581770277577
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean precision_micro: 0.8406845924993831
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean precision_macro: 0.8492342835619915
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean recall_micro: 0.6997675767050602
# Parameter set 7: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 50} - Mean recall_macro: 0.7027405928666559
#
#
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean f1_micro: 0.7719795499101634
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean f1_macro: 0.7743208069747356
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean precision_micro: 0.8456079101738849
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean precision_macro: 0.854019740296294
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean recall_micro: 0.710200323218897
# Parameter set 8: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 100} - Mean recall_macro: 0.7122779024131783
#
#
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean f1_micro: 0.7755647255554077
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean f1_macro: 0.7786960082447543
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean precision_micro: 0.849023968586117
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean precision_macro: 0.858214310314547
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean recall_micro: 0.7139551434029999
# Parameter set 9: {'classifier': RandomForestClassifier(), 'classifier__criterion': 'entropy', 'classifier__n_estimators': 150} - Mean recall_macro: 0.7165684986367417
#
#
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.18596812658106338
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.1897107040063269
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.868813137720965
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.8077879925894903
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.10430424964827607
# Parameter set 10: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.11816551681747536
#
#
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean f1_micro: 0.26880217835985765
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean f1_macro: 0.2719330166496047
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean precision_micro: 0.7347807920510521
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean precision_macro: 0.6821784265180396
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean recall_micro: 0.16465979015889562
# Parameter set 11: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 2, 'classifier__weights': 'distance'} - Mean recall_macro: 0.18061056679577212
#
#
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.20212844243921307
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.20603971992026074
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8178187095443
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6980105252302817
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.11549279122748254
# Parameter set 12: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.1293532448766238
#
#
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean f1_micro: 0.21011010683494136
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean f1_macro: 0.21446603151302596
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8326177774856065
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean precision_macro: 0.7329200881068797
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean recall_micro: 0.12042271498397945
# Parameter set 13: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 3, 'classifier__weights': 'distance'} - Mean recall_macro: 0.1345153242684868
#
#
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.1550202612068108
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.16020497935182867
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8218940666009191
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.7352322298812676
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.08566803881091231
# Parameter set 14: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.09614243416521506
#
#
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean f1_micro: 0.1712012544194792
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean f1_macro: 0.17710325398847906
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8507246616573163
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean precision_macro: 0.8108151714298026
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean recall_micro: 0.0952838690540159
# Parameter set 15: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 5, 'classifier__weights': 'distance'} - Mean recall_macro: 0.10631106159449363
#
#
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.07823561019827666
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.08414044817817778
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8543977977136095
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6996342039739873
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.04102328295063607
# Parameter set 16: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.04653054131180985
#
#
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean f1_micro: 0.14141450760813654
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean f1_macro: 0.14837665004195555
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8807756388607452
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean precision_macro: 0.8691244387973864
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean recall_micro: 0.07697052366782502
# Parameter set 17: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 8, 'classifier__weights': 'distance'} - Mean recall_macro: 0.08520911490290253
#
#
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean f1_micro: 0.08067653607354994
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean f1_macro: 0.08658479713133103
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean precision_micro: 0.8412585034013607
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean precision_macro: 0.6770225928755341
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean recall_micro: 0.042391666857614814
# Parameter set 18: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform'} - Mean recall_macro: 0.04797061487905336
#
#
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean f1_micro: 0.11729691788927303
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean f1_macro: 0.12453153201625011
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean precision_micro: 0.8901779515742867
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean precision_macro: 0.838597958414135
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean recall_micro: 0.06283600764020769
# Parameter set 19: {'classifier': KNeighborsClassifier(), 'classifier__n_neighbors': 9, 'classifier__weights': 'distance'} - Mean recall_macro: 0.06970159635435695
#
#
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.0
# Parameter set 20: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.0
#
#
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.0
# Parameter set 21: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.0
#
#
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.0
# Parameter set 22: {'classifier': SVC(), 'classifier__C': 0.01, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.0
#
#
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.5454573373029333
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.5388677781294027
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.8650977589785862
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.8770344233514272
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.3984108702827305
# Parameter set 23: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.40127812666937956
#
#
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.1125424685681077
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.11491862560647532
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.9452590799031476
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.6351550211736237
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.05985298086327175
# Parameter set 24: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.07286382282074112
#
#
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.45134387739595716
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.41739404171385425
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.7552251655061191
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.8291573653975322
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.3222356020223455
# Parameter set 25: {'classifier': SVC(), 'classifier__C': 0.1, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.3061128660791712
#
#
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean f1_micro: 0.767221745158452
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean f1_macro: 0.7714733197937083
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean precision_micro: 0.8397197032363414
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean precision_macro: 0.851438068698134
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean recall_micro: 0.7062959568365945
# Parameter set 26: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'linear'} - Mean recall_macro: 0.7077624588578645
#
#
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean f1_micro: 0.7216311041235042
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean f1_macro: 0.7219103882754024
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean precision_micro: 0.8352998418519855
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean precision_macro: 0.8487860451209093
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean recall_micro: 0.6352200937556399
# Parameter set 27: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'rbf'} - Mean recall_macro: 0.6323708368958028
#
#
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean f1_micro: 0.6120374710781823
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean f1_macro: 0.5989849577073855
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean precision_micro: 0.6474460561050434
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean precision_macro: 0.6557650609315487
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean recall_micro: 0.5857146922080022
# Parameter set 28: {'classifier': SVC(), 'classifier__C': 1.0, 'classifier__kernel': 'sigmoid'} - Mean recall_macro: 0.5762747363739285
#
#
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean f1_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean f1_macro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean precision_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean precision_macro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean recall_micro: 0.0
# Parameter set 29: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 50} - Mean recall_macro: 0.0
#
#
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean f1_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean f1_macro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean precision_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean precision_macro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean recall_micro: 0.0
# Parameter set 30: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 100} - Mean recall_macro: 0.0
#
#
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean f1_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean f1_macro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean precision_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean precision_macro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean recall_micro: 0.0
# Parameter set 31: {'classifier': LogisticRegression(), 'classifier__C': 0.01, 'classifier__max_iter': 200} - Mean recall_macro: 0.0
#
#
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean f1_micro: 0.3326042424006643
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean f1_macro: 0.33343813902596836
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean precision_micro: 0.8700770387419894
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean precision_macro: 0.8728017635708069
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean recall_micro: 0.20573710044440063
# Parameter set 32: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 50} - Mean recall_macro: 0.20726682221805973
#
#
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean f1_micro: 0.3326042424006643
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean f1_macro: 0.33343813902596836
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean precision_micro: 0.8700770387419894
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean precision_macro: 0.8728017635708069
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean recall_micro: 0.20573710044440063
# Parameter set 33: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 100} - Mean recall_macro: 0.20726682221805973
#
#
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean f1_micro: 0.3326042424006643
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean f1_macro: 0.33343813902596836
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean precision_micro: 0.8700770387419894
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean precision_macro: 0.8728017635708069
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean recall_micro: 0.20573710044440063
# Parameter set 34: {'classifier': LogisticRegression(), 'classifier__C': 0.1, 'classifier__max_iter': 200} - Mean recall_macro: 0.20726682221805973
#
#
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean f1_micro: 0.7183241677028327
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean f1_macro: 0.7189219738531236
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean precision_micro: 0.835944744242181
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean precision_macro: 0.848096635652337
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean recall_micro: 0.6299681364790228
# Parameter set 35: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 50} - Mean recall_macro: 0.6277740927569033
#
#
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean f1_micro: 0.7183241677028327
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean f1_macro: 0.7189219738531236
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean precision_micro: 0.835944744242181
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean precision_macro: 0.848096635652337
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean recall_micro: 0.6299681364790228
# Parameter set 36: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 100} - Mean recall_macro: 0.6277740927569033
#
#
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean f1_micro: 0.7183241677028327
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean f1_macro: 0.7189219738531236
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean precision_micro: 0.835944744242181
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean precision_macro: 0.848096635652337
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean recall_micro: 0.6299681364790228
# Parameter set 37: {'classifier': LogisticRegression(), 'classifier__C': 1.0, 'classifier__max_iter': 200} - Mean recall_macro: 0.6277740927569033

# %%
# Display the best parameter and create the best model
best_score_idx = clf.cv_results_['mean_test_f1_micro'].argmax()
best_params = {k.replace('classifier__', ''): v for k, v in clf.cv_results_['params'][best_score_idx].items()}
print(f'Best parameters: {best_params}')

f1_micro_score = clf.cv_results_['mean_test_f1_micro'][best_score_idx]
print('Mean f1_micro score:', f1_micro_score)

if f1_micro_score > best_model_f1_score:
    best_model_method = 'ClassifierChain'
    best_model_params = best_params
    best_model_f1_score = f1_micro_score
# Out:
# Best parameters: {'classifier': RandomForestClassifier(), 'criterion': 'gini', 'n_estimators': 150}
# Mean f1_micro score: 0.781287681264449

# %% [markdown]
# #### Getting the best model and performing some predictions

# %%
params = {key: value for key, value in best_model_params.items() if key != 'classifier'}
BaseClassifier = best_model_params['classifier']
BaseClassifier.set_params(**params)

if best_model_method == 'BinaryRelevance':
    best_model = BinaryRelevance(BaseClassifier)
elif best_model_method == 'LabelPowerset':
    best_model = LabelPowerset(BaseClassifier)
elif best_model_method == 'ClassifierChain':
    best_model = ClassifierChain(BaseClassifier)
else:
    raise TimeoutError('Unable to find the best model')

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

accuracy_value = accuracy_score(y_test, y_pred)
hamming_loss_value = hamming_loss(y_test, y_pred)

print(best_model)
print('Micro F1 score:', best_model_f1_score)
print('Accuracy score:', accuracy_value)
print('Hamming loss:', hamming_loss_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23096\1339589754.py in <module>
#      15 y_pred = best_model.predict(X_test)
#      16
# ---> 17 accuracy_value = accuracy_score(y_test, y_pred)
#      18 hamming_loss_value = hamming_loss(y_test, y_pred)
#      19
#
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [477, 3806]

# %%
from sklearn.metrics import classification_report, accuracy_score, hamming_loss

# Lựa chọn mô hình tốt nhất từ tham số
params = {key: value for key, value in best_model_params.items() if key != 'classifier'}
BaseClassifier = best_model_params['classifier']
BaseClassifier.set_params(**params)

if best_model_method == 'BinaryRelevance':
    best_model = BinaryRelevance(BaseClassifier)
elif best_model_method == 'LabelPowerset':
    best_model = LabelPowerset(BaseClassifier)
elif best_model_method == 'ClassifierChain':
    best_model = ClassifierChain(BaseClassifier)
else:
    raise TimeoutError('Unable to find the best model')

# Huấn luyện mô hình
best_model.fit(X_train, y_train)

# Dự đoán trên tập kiểm tra
y_pred = best_model.predict(X_test)

# Đánh giá kết quả
accuracy_value = accuracy_score(y_test, y_pred)
hamming_loss_value = hamming_loss(y_test, y_pred)

# Tạo báo cáo đầy đủ
classification_report_str = classification_report(y_test, y_pred, zero_division=0)  # zero_division để tránh lỗi chia 0

# In ra các kết quả
print("Best Model:", best_model)
print("Micro F1 score:", best_model_f1_score)
print("Accuracy score:", accuracy_value)
print("Hamming loss:", hamming_loss_value)
print("\nClassification Report:")
print(classification_report_str)

# %% [markdown]
# ### Model exportation using Joblib

# %%
import joblib

best_model.save('best_model.h5')
# Out:
# ['Review_Tagger_Model.pkl']
